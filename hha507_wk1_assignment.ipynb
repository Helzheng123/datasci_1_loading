# %% [markdown]
# <a href="https://colab.research.google.com/github/Helzheng123/datasci_1_loading/blob/main/hha507_wk1_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import plotly as plt

# %%
# !pip freeze > packages.txt

# %% [markdown]
# ## CSV Datasets

# %% [markdown]
# ### Description of AQI file: This data contains the Air Quality Index (AQI) score of countries around the world.

# %% [markdown]
# | Column | Description of Column |
# |--|--|
# | Date | The date that the AQI was taken |
# | Country | The country that the AQI was taken at |
# | Status | AQI quality |
# | AQI Value | How clean or polluted the air is |

# %%
# Load the file
AQI = pd.read_csv('data_date.csv')
AQI.head(10)
# Out:
#          Date     Country                          Status  AQI Value
# 0  2022-07-21     Albania                            Good         14
# 1  2022-07-21     Algeria                        Moderate         65
# 2  2022-07-21     Andorra                        Moderate         55
# 3  2022-07-21      Angola  Unhealthy for Sensitive Groups        113
# 4  2022-07-21   Argentina                        Moderate         63
# 5  2022-07-21     Armenia                        Moderate         76
# 6  2022-07-21   Australia                        Moderate         56
# 7  2022-07-21     Austria                            Good         45
# 8  2022-07-21  Azerbaijan                            Good         12
# 9  2022-07-21     Bahrain                       Unhealthy        165

# %% [markdown]
# ### Description of respiratory file: This contains different chronic respiratory diseases data collected from the public health department of the state New Mexico.

# %% [markdown]
# | Column | Description of Column|
# |--|--|
# | Symptoms | The symptoms the individual faces |
# | Age | Age of individual |
# | Sex | Sex of individual |
# | Disease | Type of respiratory disease the individual has |
# | Treatment | Type of treatment the individual receives |
# | Nature | Condition of the disease |

# %%
respiratory = pd.read_csv('respiratory symptoms and treatment.csv')
respiratory.head(10)
# Out:
#                      Symptoms   Age     Sex Disease    Treatment  Nature
# 0                   coughing    5.0  female  Asthma   Omalizumab    high
# 1  tight feeling in the chest   4.0  female  Asthma  Mepolizumab    high
# 2                    wheezing   6.0    male  Asthma  Mepolizumab    high
# 3         shortness of breath   7.0    male  Asthma  Mepolizumab    high
# 4         shortness of breath   9.0    male  Asthma  Mepolizumab    high
# 5  tight feeling in the chest   NaN    male  Asthma  Mepolizumab    high
# 6         shortness of breath   NaN    male  Asthma  Mepolizumab    high
# 7  tight feeling in the chest   8.0  female  Asthma  Mepolizumab    high
# 8         shortness of breath  36.0  female  Asthma  Mepolizumab  medium
# 9                    wheezing  40.0  female  Asthma   Omalizumab  medium

# %% [markdown]
# ## XLSX Datasets

# %% [markdown]
# ### Description of flight_info file: This data contains dataset for flight booking through *Ease My Trip*.

# %% [markdown]
# | Column | Description of Column |
# |--|--|
# | Airline | The organization that provides the route |
# | Date_of_Journey | The date the flight will take place|
# | Source | The location the flight departs from |
# | Destination | The location the flight arrives at |
# | Route | The location in abbreviations of where the flight departs from to the arrival destination |
# | Dep_Time | The time the flight departs |
# | Arrival_Time | The time the flight arrives |
# | Duration | The time span of the flight |
# | Total_Stops | How many stops the flight will have |
# | Additional_Info | Additional information regarding the flight |
# | Price | Price of the flight ticket |

# %%
flight_info = pd.read_excel('Data_Train.xlsx')
flight_info.head(10)
# Out:
#              Airline Date_of_Journey    Source Destination  \
# 0             IndiGo      24/03/2019  Banglore   New Delhi
# 1          Air India       1/05/2019   Kolkata    Banglore
# 2        Jet Airways       9/06/2019     Delhi      Cochin
# 3             IndiGo      12/05/2019   Kolkata    Banglore
# 4             IndiGo      01/03/2019  Banglore   New Delhi
# 5           SpiceJet      24/06/2019   Kolkata    Banglore
# 6        Jet Airways      12/03/2019  Banglore   New Delhi
# 7        Jet Airways      01/03/2019  Banglore   New Delhi
# 8        Jet Airways      12/03/2019  Banglore   New Delhi
# 9  Multiple carriers      27/05/2019     Delhi      Cochin
#
#                    Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0              BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1  CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# 2  DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h     2 stops
# ...

# %% [markdown]
# ### Description of Foreign Exchange Rates file: This is a dataset on foreign exchange rates from 2000-2019 on different countries. :

# %% [markdown]
# | Column | Description of Column |
# |--|--|
# | Time Series | Date |
# | Australia | Australia dollar per United States dollar (USD) |
# | Euro Area | Euro per USD |
# | New Zealand | New Zealand dollar per USD |
# | United Kingdom | United Kingdom pound per USD |
# | Brazil | Brazil real per USD |
# | Canada | Canadian dollar per USD |
# | China | Yuan per USD |
# | Hong Kong | Hong Kong dollar per USD |
# | India | Indian rupee per USD |
# | Korea | Won per USD |
# | Mexico | Mexican peso per USD |
# | South Africa | Rand per USD |
# | Singapore | Singapore dollar per USD |
# | Denmark | Danish Krone per USD |
# | Japan | Yen per USD |
# | Malaysia | Ringgit per USD |
# | Norway | Norwegian Krone per USD |
# | Sweden | Krona per USD |
# | Sri Lanka | Sri Lankan Rupee per USD |
# | Switzerland | Franc per USD |
# | Taiwan | New Taiwan Dollar per USD |
# | Thailand | Baht per USD |

# %%
foreign_exchange_rate = pd.read_excel('Foreign_Exchange_Rates.xlsx')
foreign_exchange_rate.head(10)
# Out:
#    Time Serie AUSTRALIA - AUSTRALIAN DOLLAR/US$ EURO AREA - EURO/US$  \
# 0  2000-01-03                            1.5172               0.9847
# 1  2000-01-04                            1.5239                 0.97
# 2  2000-01-05                            1.5267               0.9676
# 3  2000-01-06                            1.5291               0.9686
# 4  2000-01-07                            1.5272               0.9714
# 5  2000-01-10                            1.5242               0.9754
# 6  2000-01-11                            1.5209               0.9688
# 7  2000-01-12                            1.5202               0.9727
# 8  2000-01-13                            1.4954               0.9737
# 9  2000-01-14                            1.5004               0.9874
#
#   NEW ZEALAND - NEW ZELAND DOLLAR/US$  \
# 0                              1.9033
# 1                              1.9238
# 2                              1.9339
# 3                              1.9436
# ...

# %% [markdown]
# ### Description of LinkedIn Job file: This is a overview of job postings on LinkedIn

# %% [markdown]
# | Column | Description of Column |
# |--|--|
# | Job_ID | The unique ID for each job |
# | Job | The type of job |
# | Location | Location for the job |
# | Company_ID | The unique ID for the company |
# | Company_name | The name of the company |
# | Work_type | The type of job (if it is remote, on-site, or hybrid) |
# | Full_time_remote | Full time or part time |
# | No_of_employ | Number of employees |
# | No_of_application | Number of applications received |
# | posted_day_ago | The time of job posting |
# | Alumni | How many alumnis are in the company |
# | Hiring_person | Name of hiring person |
# | LinkedIn Followers | Number of followers |
# | Hiring_Person_link | Link to hiring person |
# | Job Details | About the job |

# %%
linkedin_job = pd.read_excel('linkdin_Job_data.xlsx')
linkedin_job.head(10)
# Out:
#        job_ID                                                job  \
# 0  3471657636  Data Analyst, Trilogy (Remote) - $60,000/year USD
# 1  3471669068  Data Analyst, Trilogy (Remote) - $60,000/year USD
# 2  3474349934                                 Data Analyst - WFH
# 3  3472816027                                       Data Analyst
# 4  3473311511                                       Data Analyst
# 5  3472504479                                       Data Analyst
# 6  3471658510  Data Analyst, Trilogy (Remote) - $60,000/year USD
# 7  3472808738                                  Shopify Developer
# 8  3475061559                                 Database Developer
# 9  3473336242                                  Shopify Developer
#
#                          location  company_id              company_name  \
# 0             Delhi, Delhi, India         NaN                 Crossover
# 1         New Delhi, Delhi, India         NaN                 Crossover
# ...

# %% [markdown]
# ## JSON Datasets

# %% [markdown]
# ### Description of Monkey Pox file: This is a dataset focusing on the world's monkey pox infection cases.

# %% [markdown]
# | Column | Description of Column |
# |--|--|
# | Location | The country |
# | Date | The date of the case |
# | New_cases | Number of new cases |
# | New_cases_smoothed | Number of new cases shown through smoothing techniques |
# | Total_cases | Total number of cases |
# | New_cases_per_million | Number of cases per million |
# | Total_cases_per_million | Total number of cases per million |
# | New_cases_smoothed_per_million | Number of new cases per million shown through smoothing techniques |
# | New_deaths | Number of new deaths |
# | New_deaths_smoothed | Number of new deaths shown through smoothing techniques |
# | Total_deaths | Total number of deaths |
# | New_deaths_per_million | Number of new deaths per million |
# | Total_deaths_per_million | Total number of deaths per million |
# | New_deaths_smoothed_per_million | Number of new deaths per million shown through smoothing technique |

# %%
monkey_pox = pd.read_json('MonkeyBoxer.json')
monkey_pox.head(10)
# Out:
#   location       date  new_cases  new_cases_smoothed  total_cases  \
# 0  Andorra 2022-07-25          1                 NaN            1
# 1  Andorra 2022-07-26          2                 NaN            3
# 2  Andorra 2022-07-27          0                 NaN            3
# 3  Andorra 2022-07-28          0                 NaN            3
# 4  Andorra 2022-07-29          0                 NaN            3
# 5  Andorra 2022-07-30          0                 NaN            3
# 6  Andorra 2022-07-31          0                0.43            3
# 7  Andorra 2022-08-01          0                0.29            3
# 8  Andorra 2022-08-02          0                0.00            3
# 9  Andorra 2022-08-03          0                0.00            3
#
#    new_cases_per_million  total_cases_per_million  \
# 0                 12.653                   12.653
# 1                 25.306                   37.958
# 2                  0.000                   37.958
# ...

# %% [markdown]
# ### Description of COVID Tracking file: This is a dataset that shows historic US values on COVID data for the US.

# %% [markdown]
# | Column | Description of Column |
# |--|--|
# | Date | Date of when the data was collected by the COVID Tracking Project |
# | States | Number of states/territories that was included |
# | Positive | Confirmed cases |
# | Negative | Negative PCR tests |
# | Pending | Number of tests that have not been completed/reported |
# | HospitalizedCurrently | Number of individuals currently hospitalized with COVID-19 |
# | HospitalizedCumulative | Total number of individuals hospitalized with COVID-19 |
# | InIcuCurrently | Number of individuals currently hospitalized in the ICU |
# | InIcuCumulative | Total number of individuals hospitalized in the ICU with COVID-19 |
# | OnVentilatorCurrently | Number of individuals currently on ventilator |
# | OnVentilatorCumulative | Total number of individuals on ventilator |
# | DateChecked | Has been deprecated as it was an old label for lastUpdateET |
# | Death | Total number of fatalities with COVID-19 |
# | Hospitalized | Has been deprecated as it was an old label for hospitalizedCumulative |
# | TotalTestResults | Total test results relating to COVID-19 |
# | LastModified | Has been deprecated as it was an old label for lastUpdateET |
# | Recovered | Total number of recovered individuals from COVID-19 |
# | Total | Has been deprecated as it is now computed through the addition of positive, negative, and pending values |
# | posNeg | Has been deprecated for the same reason as Total |
# | DeathIncrease |  The number of daily increases in death |
# | HospitalizedIncrease | Number of increase in hospitalizedCumulative |
# | NegativeIncrease | Number in daily increase in negative that is computed from the subtraction of the value of negative for the previous day |
# | PositiveIncrease | Number in daily increase in API field positive (from Cases) |
# | TotalTestResultsIncrease | Total number of daily increase from TotalTestResults |

# %%
covid_tracking = pd.read_json('daily.json')
covid_tracking.head(10)
# Out:
#        date  states    positive    negative  pending  hospitalizedCurrently  \
# 0  20210307      56  28756489.0  74582825.0  11808.0                40199.0
# 1  20210306      56  28714654.0  74450990.0  11783.0                41401.0
# 2  20210305      56  28654639.0  74307155.0  12213.0                42541.0
# 3  20210304      56  28585852.0  74035238.0  12405.0                44172.0
# 4  20210303      56  28520365.0  73857281.0  11778.0                45462.0
# 5  20210302      56  28453529.0  73590280.0  11196.0                46388.0
# 6  20210301      56  28399281.0  73334501.0  11748.0                46738.0
# 7  20210228      56  28351189.0  73216424.0  11708.0                47352.0
# 8  20210227      56  28296840.0  73012825.0  11731.0                48871.0
# 9  20210226      56  28225595.0  72807735.0  11945.0                51112.0
#
#    hospitalizedCumulative  inIcuCurrently  inIcuCumulative  \
# 0                776361.0          8134.0          45475.0
# ...

# %% [markdown]
# ### Description of School Ranking file: This is a dataset that shows the rankings of 311 US Universities.

# %% [markdown]
# | Column | Description of Column |
# |--|--|
# | RankingNoteText | Missing ranking (NaN) |
# | NonResponderText | If the University responded to the US News statistics |
# | NonResponder | The status of the response (False is if the University responded, True is if the University didn't respond) |
# | ACT-avg | ACT average scores |
# | Primary Photo | Link to the photo of the University |
# | Primary Photo Thumb | Thumbnail Photo link |
# | SAT-avg | SAT average scores |
# | Enrollment | Number of enrollment |
# | City | The city the University is in |
# | SortName | Name of the university |
# | DisplayName | Name of the university as displayed |
# | SchoolType | Type of school |
# | Region | Missing (NaN) |
# | AliasNames | Another name for the University |
# | RankingType | Type of ranking |
# | OverallRank | The rank of the University |
# | InstitutionalControl | Type of University |
# | RankingMaxPossibleScore| Missing (NaN) |
# | RankingRankStatus | If the University is ranked |
# | PrimaryKey | Primary key value |

# %%
school_ranking = pd.read_json('schoolInfo.json')
school_ranking.head(10)
# Out:
#    rankingNoteText nonResponderText  nonResponder  act-avg  \
# 0              NaN             None         False     32.0
# 1              NaN             None         False     32.0
# 2              NaN             None         False     32.0
# 3              NaN             None         False     32.0
# 4              NaN             None         False     32.0
# 5              NaN             None         False     33.0
# 6              NaN             None         False     31.0
# 7              NaN             None         False     32.0
# 8              NaN             None         False     31.0
# 9              NaN             None         False     34.0
#
#                                         primaryPhoto  \
# 0  https://www.usnews.com/img/college-photo_31291...
# 1  https://www.usnews.com/img/college-photo_8866.jpg
# 2  https://www.usnews.com/dims4/USNEWS/5b128f0/17...
# 3  https://www.usnews.com/dims4/USNEWS/60348dd/17...
# ...
